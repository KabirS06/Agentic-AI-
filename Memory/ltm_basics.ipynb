# %%
from langgraph.store.memory import InMemoryStore

# %%
#Creating store
store=InMemoryStore()

# %%
#Creating a namespace
namespace=('user','u1')   #similar to a folder in memory
#  user
#  |-u1         (Folder in a folder)

# %% [markdown]
# ## Creating Memories

# %%
store.put(namespace , "1",{"data":"user prefers c++"})
store.put(namespace , "2",{'data':"Users Prefer dark mode"})

# %%
# another namespace 
namespace2=('user','u2')

# adding Memories
store.put(namespace2,'1',{'data':'User prefers python'})
store.put(namespace2,'2',{'data':'user loves oreo milkshake'})

# %% [markdown]
# ## Retrieving Memories

# %%
store.get(namespace,'1')
# Out:
# Item(namespace=['user', 'u1'], key='1', value={'data': 'user prefers c++'}, created_at='2026-08-16T16:16:37.394028+00:00', updated_at='2026-08-16T16:16:37.394029+00:00')

# %%
store.get(namespace2,'2')
# Out:
# Item(namespace=['user', 'u2'], key='2', value={'data': 'user loves oreo milkshake'}, created_at='2026-08-16T16:16:35.280466+00:00', updated_at='2026-08-16T16:16:35.280466+00:00')

# %% [markdown]
# ## Retrieving all Memories

# %%
items=store.search(namespace)

for item in items:
    print(item.value)
# Out:
# {'data': 'user prefers c++'}
# {'data': 'Users Prefer dark mode'}

# %% [markdown]
# ## Semantic Search

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
embedding_model=HuggingFaceEmbeddings(model='all-MiniLM-L6-v2')
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1199.91it/s]

# %%
store=InMemoryStore(index={'embed':embedding_model,'dims':1536})

# %%
namespace=('users','u1')

# %%
store.put(namespace, "1", {"data": "User prefers concise answers over long explanations"})
store.put(namespace, "2", {"data": "User likes examples in Python"})
store.put(namespace, "3", {"data": "User usually works late at night"})
store.put(namespace, "4", {"data": "User prefers dark mode in applications"})
store.put(namespace, "5", {"data": "User is learning machine learning"})
store.put(namespace, "6", {"data": "User dislikes overly theoretical explanations"})
store.put(namespace, "7", {"data": "User prefers step-by-step reasoning"})
store.put(namespace, "8", {"data": "User is based in India"})
store.put(namespace, "9", {"data": "User likes real-world analogies"})
store.put(namespace, "10", {"data": "User prefers bullet points over paragraphs"})

# %%
items=store.search(namespace,query="What is user learning",limit=1)
for item in items:
    print(item.value)
# Out:
# {'data': 'User is learning machine learning'}

# %%
items=store.search(namespace,query="What are users preferences",limit=3)

for item in items:
    print(item.value)
# Out:
# {'data': 'User prefers dark mode in applications'}
# {'data': 'User likes examples in Python'}
# {'data': 'User likes real-world analogies'}
