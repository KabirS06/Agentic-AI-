# %%
from dotenv import load_dotenv
load_dotenv()

import uuid
from typing import List
from pydantic import BaseModel , Field

from langchain_core.messages import SystemMessage
from langchain_groq import ChatGroq
from langchain_core.runnables import RunnableConfig

from langgraph.graph import START , END , StateGraph , MessagesState
from langgraph.store.memory import InMemoryStore
from langgraph.store.base import BaseStore

# %%
store=InMemoryStore()

# %%
SYSTEM_PROMPT_TEMPLATE = """You are a helpful assistant with memory capabilities.
If user-specific memory is available, use it to personalize 
your responses based on what you know about the user.

Your goal is to provide relevant, friendly, and tailored 
assistance that reflects the user’s preferences, context, and past interactions.

If the user’s name or relevant personal context is available, always personalize your responses by:
    – Always Address the user by name (e.g., "Sure, Nitish...") when appropriate
    – Referencing known projects, tools, or preferences (e.g., "your MCP server python based project")
    – Adjusting the tone to feel friendly, natural, and directly aimed at the user

Avoid generic phrasing when personalization is possible.

Use personalization especially in:
    – Greetings and transitions
    – Help or guidance tailored to tools and frameworks the user uses
    – Follow-up messages that continue from past context

Always ensure that personalization is based only on known user details and not assumed.

In the end suggest 3 relevant further questions based on the current response and user profile

The user’s memory (which may be empty) is provided as: {user_details_content}
"""

# %%
memory_llm=ChatGroq(model='openai/gpt-oss-120b')

# %%
class MemoryItem(BaseModel):
    text :str =Field(description='Atomic user memory')
    is_new :bool=Field(description='True if the following memory is new  , false if it already exist')

# %%
class MemoryDecision(BaseModel):
    should_write:bool =Field(description='Whether to store any memories ?')
    memories :List[MemoryItem] =Field(description='Atomic user memory to store')

# %%
memory_extractor=memory_llm.with_structured_output(MemoryDecision)

# %%
MEMORY_PROMPT = """You are responsible for updating and maintaining accurate user memory.

CURRENT USER DETAILS (existing memories):
{user_details_content}

TASK:
- Review the user's latest message.
- Extract user-specific info worth storing long-term (identity, stable preferences, ongoing projects/goals).
- For each extracted item, set is_new=true ONLY if it adds NEW information compared to CURRENT USER DETAILS.
- If it is basically the same meaning as something already present, set is_new=false.
- Keep each memory as a short atomic sentence.
- No speculation; only facts stated by the user.
- If there is nothing memory-worthy, return should_write=false and an empty list.
"""

# %%
def remember_node(state : MessagesState ,config :RunnableConfig ,store :BaseStore ):
    user_id=config['configurable']['user_id']

    namespace=('user',user_id,'details')

    items=store.search(namespace)

    existing = "\n".join(it.value["data"] for it in items) if items else "(empty)"

    # last user message
    last_msg = state["messages"][-1].content

    decision: MemoryDecision = memory_extractor.invoke(
        [
            SystemMessage(content=MEMORY_PROMPT.format(user_details_content=existing)),
            {"role": "user", "content": last_msg},
        ]
    )

    if decision.should_write:
        for mem in decision.memories:
            if mem.is_new:
                store.put(namespace, str(uuid.uuid4()), {"data": mem.text})

    return {}

# %%
chat_llm=ChatGroq(model='openai/gpt-oss-120b')

# %%
def chat_node(state: MessagesState, config: RunnableConfig, *, store: BaseStore):
    user_id = config["configurable"]["user_id"]
    ns = ("user", user_id, "details")

    items = store.search(ns)
    user_details = "\n".join(it.value["data"] for it in items) if items else ""

    system_msg = SystemMessage(
        content=SYSTEM_PROMPT_TEMPLATE.format(
            user_details_content=user_details or "(empty)"
        )
    )

    response = chat_llm.invoke([system_msg] + state["messages"])
    return {"messages": [response]}

# %%
builder = StateGraph(MessagesState)
builder.add_node("remember", remember_node)
builder.add_node("chat", chat_node)

builder.add_edge(START, "remember")
builder.add_edge("remember", "chat")
builder.add_edge("chat", END)

graph = builder.compile(store=store)

graph

# %%
config = {"configurable": {"user_id": "u1"}}

# %%
result = graph.invoke({"messages": [{"role": "user", "content": "Hi, my name is Kabir "}]}, config)
result['messages'][-1].content
# Out:
# 'Hey Kabir! 👋 Great to meet you. How can I help you today?  \n\n**Here are a few things you might want to explore next:**\n\n1. **What kind of project are you working on right now?** (e.g., web development, data analysis, automation)  \n2. **Do you need help with a specific programming language or tool?** (Python, JavaScript, Docker, etc.)  \n3. **Are you looking for resources or tutorials on a particular topic?** (machine learning, cloud deployment, UI/UX design)\n\nFeel free to pick any of those or let me know something else you’re curious about!'

# %%
for it in store.search(("user", "u1", "details")):
    print(it.value["data"])
# Out:
# The user’s name is Kabir.

# %%
result = graph.invoke({"messages": [{"role": "user", "content": "I am student pursuing BTech in CSE "}]}, config)
print(result['messages'][-1].content)
# Out:
# Hey Kabir! 🎓
#
# It’s great to hear you’re pursuing a BTech in Computer Science and Engineering. Whether you’re tackling data structures, diving into algorithms, working on a cool project, or thinking about internships, I’m here to help.
#
# What are you working on right now, or is there a particular topic you’d like some guidance on? Feel free to let me know—whether it’s study strategies, coding help, project ideas, or anything else related to your CSE journey.
#
# ---
#
# **Here are three follow‑up questions you might find useful:**
#
# 1. Are there any specific subjects or concepts in your CSE curriculum that you’d like clarified or extra practice with?
# 2. Do you have a personal or academic project in mind that you’d like help planning or debugging?
# 3. Are you exploring internship or job opportunities, and would you like tips on building a strong resume or preparing for technical interviews?

# %%
for it in store.search(("user", "u1", "details")):
    print(it.value["data"])
# Out:
# The user’s name is Kabir.
# The user is a BTech student in Computer Science and Engineering.

# %%
result = graph.invoke({"messages": [{"role": "user", "content": "Explain GenAI simply"}]}, config)
print(result['messages'][-1].content)
# Out:
# Sure, Kabir—let’s break down Generative AI (Gen AI) in a way that clicks with a BTech CS student.
#
# ---
#
# ## 1. What “generative” means
# - **Generative** = *creates something new* (text, images, music, code, etc.) rather than just classifying or retrieving existing data.
# - Think of it as a **smart composer** that learns patterns from a huge dataset and then writes its own “songs” that follow those patterns.
#
# ## 2. Core idea in a nutshell
# 1. **Training phase** – A neural network (usually a **Transformer**) is fed massive amounts of data (e.g., books, code repositories, images).
# 2. **Learning phase** – The model learns statistical relationships: “If I see this context, the next word/pixel/command is likely X.”
# 3. **Generation phase** – Given a prompt, the model samples from those learned probabilities to produce a fresh output.
#
# ## 3. How it actually works (high‑level)
# | Step | What happens | Analogy |
# |------|--------------|---------|
# | **Input (prompt)** | You give a short instruction or seed (e.g., “Write a Python function to reverse a list”). | You hand a composer a melody fragment. |
# | **Context encoding** | The model converts the prompt into vectors (embeddings) that capture meaning. | The composer reads the fragment and understands its key and mood. |
# | **Self‑attention** | Each token “looks at” every other token to decide how much it should influence the next token. | Musicians listening to each other to stay in sync. |
# | **Probability distribution** | The model predicts a distribution over the next possible token. | The composer considers many possible notes that could follow. |
# | **Sampling** | A token is chosen (greedy, top‑k, nucleus sampling, etc.) and appended to the output. | The composer picks the most fitting note and writes it down. |
# | **Iterate** | Steps repeat until a stop condition (length, end‑of‑sentence token, etc.). | The piece keeps growing until it feels complete. |
#
# ## 4. Types of Gen AI you’ll encounter
# | Modality | Example models | Typical use |
# |----------|----------------|-------------|
# | **Text** | GPT‑4, LLaMA, Claude | Chatbots, code assistants, essay drafting |
# | **Images** | DALL·E, Stable Diffusion, Midjourney | Art generation, design mock‑ups |
# | **Audio** | Jukebox, Riffusion | Music composition, voice synthesis |
# | **Multimodal** | GPT‑4V, LLaVA | Combine text+image, e.g., “Describe this picture.” |
#
# ## 5. Why it matters for a CS student
# - **Rapid prototyping** – You can ask a model to scaffold code, write unit tests, or explain algorithms.
# - **Creative tooling** – Generate UI mockups, diagrams, or documentation with a single prompt.
# - **Research** – Explore new model architectures, fine‑tune on domain‑specific data, or build custom assistants.
#
# ## 6. Common misconceptions
# | Myth | Reality |
# |------|----------|
# | “Gen AI *understands* everything it says.” | It predicts patterns; it doesn’t have true comprehension or intent. |
# | “It always produces perfect output.” | Hallucinations happen—outputs can be plausible but factually wrong. |
# | “You can’t control it.” | Prompt engineering, temperature settings, and fine‑tuning let you steer behavior. |
#
# ## 7. A quick code‑style example (Python + OpenAI API)
#
# ```python
# import openai
#
# openai.api_key = "YOUR_KEY"
#
# prompt = "Write a Python function that checks if a number is prime."
#
# response = openai.ChatCompletion.create(
#     model="gpt-4o-mini",
#     messages=[{"role": "user", "content": prompt}],
#     temperature=0.2   # lower = more deterministic
# )
#
# print(response.choices[0].message.content)
# ```
#
# Running this will give you a ready‑to‑use function—great for quick experiments or learning how a model structures code.
#
# ---
#
# ### TL;DR
# Generative AI is a class of models that **learn** from massive datasets and then **create** new content (text, images, code, etc.) by predicting the most likely next piece of data, step by step. It’s built on transformer architectures, uses self‑attention to capture context, and can be steered with prompts and parameters.
#
# ---
#
# #### Want to dive deeper? Here are three follow‑up questions you might find useful:
#
# 1. **“How can I fine‑tune a pre‑trained language model on my own dataset of Java code?”**
# 2. **“What are the best practices for prompt engineering to reduce hallucinations in text generation?”**
# 3. **“Can you walk me through building a simple image‑to‑text (captioning) pipeline using a multimodal model?”**
#
# Feel free to pick any, and we can explore it together!

# %%
for it in store.search(("user", "u1", "details")):
    print(it.value["data"])
# Out:
# The user’s name is Kabir.
# The user is a BTech student in Computer Science and Engineering.
